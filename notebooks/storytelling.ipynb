# %% [markdown]
# ## Storytelling

# %%
import pandas as pd
import matplotlib as mpl
import src.shootingsapi as sa

# %%
shootings = pd.read_csv("../output/shootings_clean.csv", index_col="Date")
shootings.index = pd.to_datetime(shootings.index)

# %%
shootings.head()
# Out:
#              Manner of Death       Armed   Age Gender                 Race  \
# Date
# 2015-01-02              Shot         Gun  53.0   Male                Asian
# 2015-01-02              Shot         Gun  47.0   Male  White, non-Hispanic
# 2015-01-03  Shot and Tasered     Unarmed  23.0   Male             Hispanic
# 2015-01-04              Shot  Toy Weapon  32.0   Male  White, non-Hispanic
# 2015-01-04              Shot    Nail Gun  39.0   Male             Hispanic
#
#                      City       State  Signs of Mental Illness Threat Level  \
# Date
# 2015-01-02        Shelton  Washington                     True       Attack
# 2015-01-02          Aloha      Oregon                    False       Attack
# 2015-01-03        Wichita      Kansas                    False        Other
# 2015-01-04  San Francisco  California                     True       Attack
# 2015-01-04          Evans    Colorado                    False       Attack
#
# ...

# %%
sa.count_total(shootings, state="California")

# %%
sa.count_total(shootings)

# %%
sa.show_trend(shootings)

# %%
sa.show_trend(shootings, attr="Gender")

# %%
sa.show_trend(shootings, attr="Race")

# %%
sa.show_trend(shootings, time_interval=(2018, 2020), state="California")

# %%
sa.show_trend(shootings, time_interval=(2018, 2020), city="Los Angeles")

# %%
sa.age_dist(shootings)

# %%
sa.age_dist(shootings, state="Texas")

# %%
sa.age_dist(shootings, rows="Signs of Mental Illness", cols="Gender")

# %%
sa.age_dist(shootings, rows="Flee", cols="Gender")

# %%
sa.race_pie(shootings)

# %%
sa.race_pie(shootings, time_interval=(2015, 2018), attr="Gender")

# %%
sa.race_pie(shootings, attr="Signs of Mental Illness", state="Texas")

# %%
sa.race_pie(shootings, attr="Manner of Death", state="Arizona")

# %%
sa.top_arms(shootings, top=10)

# %%
sa.top_arms(shootings, attr="Signs of Mental Illness")

# %%
sa.top_arms(shootings, attr="Race", top=3, percentage=True)

# %%
sa.top_arms(shootings, attr="Manner of Death", percentage=True, time_interval=(2018, 2020), state="California")
